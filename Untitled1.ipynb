# %%
import numpy as np
import pandas as pd

# %%
# !pip install SciencePlots
import matplotlib.pyplot as plt
plt.style.reload_library()
plt.style.use(['nature','no-latex'])

# %%
points = np.array([[0.4, 0.1], [0.75, 0.15], [0.1, 0.3], [0.5, 0.35], [0.25, 0.5], [0.8, 0.5],
                   [0.6, 0.8], [0.13, 0.86], [0.9, 0.9]])
from scipy.spatial import Voronoi, voronoi_plot_2d
vor = Voronoi(points)

# %%
import matplotlib.pyplot as plt
fig = voronoi_plot_2d(vor)
ax=fig.axes
plt.figure(figsize = (1.8,1.8),dpi=600)
plt.style.use('nature')
plt.show()
plt.savefig('test.png')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-18-c4bb324f407c> in <module>()
#       2 fig = voronoi_plot_2d(vor)
#       3 ax=fig.axes
# ----> 4 ax.autoscale(tight=False)
#       5 plt.figure(figsize = (1.8,1.8),dpi=600)
#       6 plt.style.use('nature')
#
# AttributeError: 'list' object has no attribute 'autoscale'

# %%
import pandas as pd
# basics graphs - bar, line, histogram, pie, scatter
import matplotlib.pyplot as plt
# descriptive plot - relation b/w , pairplot, density
import seaborn as sns
import numpy as np

# %%
# Reading Dataset
data = pd.read_csv('Summer and Fall 2021 Students Data Sheet.csv')

# %%
data
# Out:
#             F University Name Name  ... Unnamed: 23 Unnamed: 24 Unnamed: 25
# 0         NaN             NaN  NaN  ...         NaN         NaN         NaN
# 1         NaN             NaN  NaN  ...         NaN         NaN         NaN
# 2     Alabama             NaN  NaN  ...         NaN         NaN         NaN
# 3         NaN             NaN  NaN  ...         NaN         NaN         NaN
# 4         NaN             NaN  NaN  ...         NaN         NaN         NaN
# ...       ...             ...  ...  ...         ...         ...         ...
# 2678      NaN             NaN  NaN  ...         NaN         NaN         NaN
# 2679      NaN             NaN  NaN  ...         NaN         NaN         NaN
# 2680      NaN             NaN  NaN  ...         NaN         NaN         NaN
# 2681      NaN             NaN  NaN  ...         NaN         NaN         NaN
# 2682      NaN             NaN  NaN  ...         NaN         NaN         NaN
#
# [2683 rows x 26 columns]

# %%
data = data.iloc[:,0:12]

# %%
data
# Out:
#             F University Name  ... Travel Date Facebook Link
# 0         NaN             NaN  ...         NaN           NaN
# 1         NaN             NaN  ...         NaN           NaN
# 2     Alabama             NaN  ...         NaN           NaN
# 3         NaN             NaN  ...         NaN           NaN
# 4         NaN             NaN  ...         NaN           NaN
# ...       ...             ...  ...         ...           ...
# 2678      NaN             NaN  ...         NaN           NaN
# 2679      NaN             NaN  ...         NaN           NaN
# 2680      NaN             NaN  ...         NaN           NaN
# 2681      NaN             NaN  ...         NaN           NaN
# 2682      NaN             NaN  ...         NaN           NaN
#
# [2683 rows x 12 columns]

# %%
data.dropna(axis = 0,how='all',inplace = True,)

# %%
data
# Out:
#                         F  ...                                      Facebook Link
# 2                 Alabama  ...                                                NaN
# 8                     NaN  ...  https://www.facebook.com/mohammadraisularefinn...
# 9                     NaN  ...             https://www.facebook.com/shoaibanwar09
# 10                    NaN  ...              https://www.facebook.com/trisha.adeba
# 11                    NaN  ...                                                NaN
# ..                    ...  ...                                                ...
# 923  District of Columbia  ...                                                NaN
# 925                   NaN  ...                https://www.facebook.com/artahmid11
# 926                   NaN  ...                https://www.facebook.com/artahmid11
# 927                Gannon  ...                                                NaN
# ...

# %%
data.iloc[:,1]=='Texas'
# Out:
# 2      False
# 8      False
# 9      False
# 10     False
# 11     False
#        ...
# 923    False
# 925    False
# 926    False
# 927    False
# 928    False
# Name: University Name, Length: 673, dtype: bool

# %%
# Out:
# Empty DataFrame
# Columns: [F, University Name, Name, Department, Term/ Semester, Visa Information, Do you have I-20?, Email Address,  Do you need Residence Partner,  Do you need Travel Partner, Travel Date, Facebook Link]
# Index: []

# %%
# Boolean Condition
data[data['University Name'] == 'University of Houston']
# Out:
#        F  ...                                      Facebook Link
# 745  NaN  ...                                                NaN
# 768  NaN  ...                                                NaN
# 769  NaN  ...                                                NaN
# 770  NaN  ...                                                NaN
# 777  NaN  ...           https://www.facebook.com/mdekramul.karim
# 779  NaN  ...  https://www.facebook.com/profile.php?id=100004...
# 786  NaN  ...                                                NaN
# 787  NaN  ...            https://www.facebook.com/raian.ferdous
# 802  NaN  ...                  https://www.facebook.com/murad.me
# 815  NaN  ...        https://web.facebook.com/mantasha.tabassum/
# 823  NaN  ...         https://www.facebook.com/d.a.anwaral.aman/
#
# [11 rows x 12 columns]

# %%
# Boolean Condition
data[data['University Name'] == 'Rice University']
# Out:
#        F  University Name  ... Travel Date                           Facebook Link
# 732  NaN  Rice University  ...         NaN  www.facebook.com/mdshajedulhoquethakur
#
# [1 rows x 12 columns]

# %%
data.loc[777,:]
# Out:
# F                                                                      NaN
# University Name                                      University of Houston
# Name                                                     Md. Ekramul Karim
# Department                                                             NaN
# Term/ Semester                                                   Fall 2021
# Visa Information                                                       NaN
# Do you have I-20?                                          Waiting for I20
# Email Address                                          ekrammbio@gmail.com
#  Do you need Residence Partner                                         yes
#  Do you need Travel Partner                                            yes
# Travel Date                                                    August 5-10
# Facebook Link                     https://www.facebook.com/mdekramul.karim
# Name: 777, dtype: object

# %%
data.loc[778,:]
# Out:
# F                                                                      NaN
# University Name                                           Lamar University
# Name                                               Md Munimul Hasan Pranto
# Department                                                             NaN
# Term/ Semester                                                   Fall 2021
# Visa Information                       Yet to fill up DS-160 and Visa Fee
# Do you have I-20?                                                      Yes
# Email Address                                   md.munimul.hasan@gmail.com
#  Do you need Residence Partner                                         NaN
#  Do you need Travel Partner                                            NaN
# Travel Date                                                     July 25-30
# Facebook Link                     https://www.facebook.com/munimul.pranto/
# Name: 778, dtype: object

# %%
data.loc[787,:]
# Out:
# F                                                                     NaN
# University Name                                     University of Houston
# Name                                               Talukdar Raian Ferdous
# Department                                        Biomedical Engineering
# Term/ Semester                                                  Fall 2021
# Visa Information                                         Waiting for I-20
# Do you have I-20?                                               Requested
# Email Address                          raianferdous1415020bme@outlook.com
#  Do you need Residence Partner                                  Undecided
#  Do you need Travel Partner                                           Yes
# Travel Date                                       August 1st - August 7th
# Facebook Link                     https://www.facebook.com/raian.ferdous
# Name: 787, dtype: object

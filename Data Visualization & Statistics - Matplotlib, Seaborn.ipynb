# %%
import pandas as pd
# basics graphs - bar, line, histogram, pie, scatter
import matplotlib.pyplot as plt
# descriptive plot - relation b/w , pairplot, density
import seaborn as sns
import numpy as np

# %%
# Reading Dataset
boston_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/boston_train.csv')

# %%
boston_df.head()
# Out:
#        CRIM    ZN  INDUS    NOX     RM   AGE     DIS  TAX  PTRATIO  MEDV
# 0   2.30040   0.0  19.58  0.605  6.319  96.1  2.1000  403     14.7  23.8
# 1  13.35980   0.0  18.10  0.693  5.887  94.7  1.7821  666     20.2  12.7
# 2   0.12744   0.0   6.91  0.448  6.770   2.9  5.7209  233     17.9  26.6
# 3   0.15876   0.0  10.81  0.413  5.961  17.5  5.2873  305     19.2  21.7
# 4   0.03768  80.0   1.52  0.404  7.274  38.3  7.3090  329     12.6  34.6

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
plt.figure(figsize = (20,9))
plt.plot(boston_df['AGE'])
plt.title('Line Plot', fontsize = 14)
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %%
# All unique values in ascending order
boston_df['AGE'].sort_values().unique()
# Out:
# array([  2.9,   6. ,   6.2,   6.5,   6.6,   6.8,   7.8,   9.8,   9.9,
#         10. ,  13.9,  14.7,  15.3,  15.7,  16.3,  17. ,  17.2,  17.5,
#         17.7,  18.4,  18.5,  18.8,  19.5,  20.1,  20.8,  21.1,  21.4,
#         21.8,  21.9,  22.3,  22.9,  23.3,  23.4,  24.8,  27.6,  27.7,
#         27.9,  28.1,  28.4,  28.8,  28.9,  29.1,  29.2,  29.3,  30.2,
#         30.8,  31.1,  31.3,  31.5,  31.9,  32. ,  32.1,  32.2,  32.3,
#         32.9,  33.1,  33.2,  33.3,  33.5,  33.8,  34.2,  34.5,  34.9,
#         35.7,  35.9,  36.1,  36.6,  36.9,  37.2,  37.3,  38.1,  38.3,
#         38.5,  38.9,  40.1,  40.3,  40.4,  40.5,  41.1,  41.9,  42.1,
#         42.2,  42.4,  42.6,  43.7,  44.4,  45. ,  45.1,  45.4,  45.6,
#         45.7,  45.8,  46.3,  46.7,  47.2,  47.6,  48. ,  49.1,  49.3,
#         49.7,  51.8,  51.9,  52.3,  52.5,  52.9,  53.2,  53.6,  53.7,
#         54. ,  54.3,  54.4,  56. ,  56.1,  56.4,  56.7,  56.8,  57.8,
#         58. ,  58.1,  58.4,  58.5,  58.7,  59.5,  59.6,  61.1,  61.4,
#         61.5,  61.8,  62.2,  63. ,  64.5,  64.7,  65.1,  65.2,  65.3,
#         65.4,  66.1,  66.2,  66.5,  66.6,  67. ,  67.6,  68.1,  68.7,
#         68.8,  69.1,  69.5,  69.6,  69.7,  70.2,  70.3,  70.4,  70.6,
#         71.6,  72.5,  72.7,  72.9,  73.1,  73.3,  73.4,  73.9,  74.3,
#         74.5,  74.8,  74.9,  75. ,  76. ,  76.5,  76.7,  76.9,  77. ,
#         77.3,  77.7,  77.8,  78.1,  78.3,  78.7,  78.9,  79.2,  79.7,
#         79.8,  79.9,  80.3,  80.8,  81.7,  81.8,  82. ,  82.5,  82.6,
#         82.9,  83. ,  83.2,  83.3,  83.4,  83.5,  83.7,  84. ,  84.1,
#         84.5,  84.6,  84.7,  85.1,  85.4,  85.5,  85.7,  86.1,  86.3,
#         86.5,  86.9,  87.3,  87.4,  87.9,  88. ,  88.4,  88.5,  88.6,
#         88.8,  89.1,  89.2,  89.4,  89.6,  89.8,  90. ,  90.3,  90.4,
#         90.8,  91.1,  91.2,  91.3,  91.4,  91.5,  91.6,  91.7,  91.8,
#         91.9,  92.1,  92.2,  92.4,  92.6,  92.7,  92.9,  93. ,  93.3,
#         93.4,  93.5,  93.6,  93.8,  93.9,  94. ,  94.1,  94.3,  94.5,
#         94.6,  94.7,  94.8,  95. ,  95.2,  95.3,  95.4,  95.6,  95.7,
#         95.8,  96. ,  96.1,  96.2,  96.4,  96.6,  96.8,  96.9,  97. ,
#         97.1,  97.2,  97.3,  97.4,  97.5,  97.7,  97.8,  97.9,  98. ,
#         98.1,  98.2,  98.3,  98.4,  98.5,  98.7,  98.8,  98.9,  99.1,
#         99.3, 100. ])

# %%
# Drop Duplicates
boston_df['AGE'].drop_duplicates()
# Out:
# 0      96.1
# 1      94.7
# 2       2.9
# 3      17.5
# 4      38.3
#        ...
# 394    29.2
# 395    65.3
# 396    56.0
# 397    82.0
# 398    78.1
# Name: AGE, Length: 290, dtype: float64

# %%
plt.figure(figsize = (20,9))
plt.plot(boston_df['AGE'].sort_values().unique(), color = 'orangered')
plt.title('Line Plot', fontsize = 14)
plt.xlabel("Row Indexes")
plt.ylabel("AGE")
plt.show()

# %% [markdown]
# ### BAR Plot
# * Bivariate/Univariate Analysis
# * Discrete / Catergorical values vs Continuous

# %%
plt.figure(figsize = (14,9))
plt.bar(x = boston_df['ZN'], height = boston_df['MEDV'], width = 1.5, color = 'turquoise')
plt.xlabel("ZN")
plt.ylabel("MEDV")
plt.show()

# %% [markdown]
# **Histogram Plots**
# * Frequency Distribution (Variance in Distribution)
# * Univariate Analysis - Range of data vs Frequence

# %%
'''
Histogram represents Frequency of groups of Data, Distribution or spread of continuous data
[4, 5, 6, 11, 15, 19, 21, 29, 33, 34, 41, 52, 53, 56, 60, 70], bins = 7
1-10  : 3
11-20 : 3
21-30 : 2
31-40 : 2
41-50 : 1
51-60 : 4
61-70 : 1
'''
# Out:
# '\nHistogram represents Frequency of groups of Data, Distribution or spread of continuous data\n[4, 5, 6, 11, 15, 19, 21, 29, 33, 34, 41, 52, 53, 56, 60, 70], bins = 7\n1-10  : 3\n11-20 : 3\n21-30 : 2\n31-40 : 2\n41-50 : 1\n51-60 : 4\n61-70 : 1\n'

# %%
plt.figure(figsize = (14,9))
plt.hist(x = boston_df['MEDV'], color = 'purple', bins = 20)
plt.title('Histogram Plot', fontsize = 14)
plt.xlabel('MEDV')
plt.ylabel('Frequency (in Range)')
plt.savefig('/content/histogram.png')
plt.show()

# %% [markdown]
# ### Scatter Plot
# * Relation b/w variables (Bivariate Analysis)

# %%
iris_df = pd.read_csv('https://raw.githubusercontent.com/ammishra08/MachineLearning/master/Datasets/iris.csv', sep = ',')
iris_df
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
iris_df['species']
# Out:
# 0         setosa
# 1         setosa
# 2         setosa
# 3         setosa
# 4         setosa
#          ...
# 145    virginica
# 146    virginica
# 147    virginica
# 148    virginica
# 149    virginica
# Name: species, Length: 150, dtype: object

# %%
iris_df['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
plt.style.use('ggplot')
plt.figure(figsize = (14,9))
plt.scatter(x = iris_df['sepal_length'], y = iris_df['petal_length'], label = 'Petal length')
plt.scatter(x = iris_df['sepal_length'], y = iris_df['sepal_width'], label = 'Sepal Width')
plt.title('Scatter Plot', fontsize = 14)
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.savefig('/content/histogram.png')
plt.legend()
plt.show()

# %% [markdown]
# **Scatter Plot using Seaborn**

# %%
plt.figure(figsize = (12,8))
sns.scatterplot( x = 'sepal_length', y = 'petal_length', data = iris_df, hue = 'species', s = 100)
plt.show()

# %% [markdown]
# **Pie Chart**

# %%
plt.figure(figsize = (8,8))
plt.pie(iris_df['species'].value_counts(), autopct='%0.2f', explode = (0,0,0.2), labels = ['setosa', 'versicolor', 'virginica'])
plt.show()

# %%
plt.figure(figsize = (11,8))
sns.distplot(boston_df['MEDV'], color = 'darkviolet')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
boston_df['MEDV'].mean()
# Out:
# 22.62550000000001

# %%
boston_df['MEDV'].median()
# Out:
# 21.4

# %%
plt.figure(figsize = (11,8))
sns.distplot(boston_df['MEDV'], color = 'k', hist= False)
plt.axvline(x = boston_df['MEDV'].median(), color = 'b', linestyle = '--')
plt.axvline(x = boston_df['MEDV'].mean(), color = 'r', linestyle = '--')
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
sns.set_style('whitegrid')
plt.figure(figsize=(11,8))
sns.boxplot(data = iris_df, orient = 'h', palette='plasma')

# %% [markdown]
# **Correlation**

# %%
# Correlation will have range b/w -1 to +1
boston_df.corr(method = 'pearson')
# Out:
#              CRIM        ZN     INDUS  ...       TAX   PTRATIO      MEDV
# CRIM     1.000000 -0.197764  0.383433  ...  0.563791  0.284306 -0.375836
# ZN      -0.197764  1.000000 -0.532929  ... -0.323539 -0.393904  0.365931
# INDUS    0.383433 -0.532929  1.000000  ...  0.722435  0.386248 -0.465083
# NOX      0.407698 -0.521745  0.758157  ...  0.664923  0.185284 -0.410425
# RM      -0.219043  0.328418 -0.393738  ... -0.302268 -0.395436  0.685041
# AGE      0.350003 -0.561062  0.644559  ...  0.521723  0.260205 -0.368922
# DIS     -0.377643  0.665677 -0.717796  ... -0.555040 -0.227288  0.236714
# TAX      0.563791 -0.323539  0.722435  ...  1.000000  0.473023 -0.449570
# PTRATIO  0.284306 -0.393904  0.386248  ...  0.473023  1.000000 -0.531764
# MEDV    -0.375836  0.365931 -0.465083  ... -0.449570 -0.531764  1.000000
#
# [10 rows x 10 columns]

# %%
plt.figure(figsize = (14,9))
sns.heatmap(boston_df.corr(), cmap = 'RdPu', annot = True)

# %%
# If corr b/w two continuous data is closer to zero = There is no or weak relation b/w both
# If corr b/w two continuous data is closer to +1 (>0.85) = It is a positive relation b/w both (Directly Proportional)
# If corr b/w two continuous data is closer to -1 (<-0.85) = It is a negative relation b/w both (Inversely Proportional)

# %%
# Reading Dataset
results_df = pd.read_csv('Results.csv')

# %%
display(results_df)
# Out:
#        HR  thickness  wetting    wall  liquid  time (ns)
# 0   320.0        3.0      0.5  341.85  133.24       1.79
# 1   320.0        4.0      0.5  335.57  125.27       1.77
# 2   320.0        5.0      0.5  334.43  124.80       1.78
# 3   320.0        6.0      0.5  345.22  122.73       1.80
# 4   160.0        5.0      0.5  250.00  133.00       2.50
# 5   160.0        6.0      0.5  250.00  128.00       2.46
# 6    80.0        5.0      0.5  250.00  133.00       3.15
# 7    80.0        6.0      0.5  250.00  133.00       3.15
# 8    40.0        5.0      0.5  242.00  146.00       4.74
# 9    40.0        6.0      0.5  231.00  138.00       4.50
# 10  320.0        3.0      2.0  223.00  144.00       1.43
# 11  320.0        4.0      2.0  220.00  138.00       1.42
# 12  320.0        5.0      2.0  220.00  131.00       1.42
# 13  320.0        6.0      2.0  220.00  129.00       1.42
# 14  160.0        3.0      2.0  203.00  147.00       1.72
# 15  160.0        4.0      2.0  202.00  139.00       1.72
# 16  160.0        5.0      2.0  200.00  135.00       1.70
# 17  160.0        6.0      2.0  200.00  133.00       1.69
# 18   80.0        4.0      2.0  188.00  147.00       2.24
# 19   80.0        5.0      2.0  187.00  140.00       2.22
# 20   80.0        6.0      2.0  187.00  134.00       2.22
# 21   40.0        5.0      2.0  177.00  147.00       3.17
# 22   40.0        6.0      2.0  175.00  143.00       3.16
# 23  320.0        3.0      4.0  214.00  149.00       1.40
# 24  320.0        4.0      4.0  209.00  141.00       1.39
# 25  320.0        5.0      4.0  207.00  134.00       1.38
# 26  320.0        6.0      4.0  206.00  131.00       1.37
# 27  160.0        3.0      4.0  197.00  144.00       1.69
# 28  160.0        4.0      4.0  191.00  138.00       1.65
# 29  160.0        5.0      4.0  191.00  134.00       1.65
# 30  160.0        6.0      4.0  191.00  149.00       1.64
# 31   80.0        4.0      4.0  185.00  151.00       2.20
# 32   80.0        5.0      4.0  181.00  141.00       2.16
# 33   80.0        6.0      4.0  177.00  136.00       2.11
# 34   40.0        5.0      4.0  173.00  148.00       3.09
# 35   40.0        6.0      4.0  169.00  143.00       3.02

# %%
results_df = results_df.drop('time (ns)',axis = 1)

# %%
plt.figure(figsize = (14,9))
sns.heatmap(results_df.corr(), cmap = 'RdPu', annot = True)

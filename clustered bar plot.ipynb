# %%
import pandas as pd
# basics graphs - bar, line, histogram, pie, scatter
import matplotlib.pyplot as plt
# descriptive plot - relation b/w , pairplot, density
import seaborn as sns
import numpy as np

# %%
# Reading Dataset
df = pd.read_excel('/content/moduli_from_flexure.xlsx',sheet_name='plot')

# %%
df
# Out:
#         category  Flexural Modulus (MPa)       sd_FM  \
# 0   Pressed in Y              256.663333  126.089454
# 1  Pressed in YZ             1166.433333   53.457418
# 2   Pressed in Z              103.504000    6.176000
# 3  Pressed in ZY              945.146667   78.869057
# 4   Freeze dried               45.794000    3.301320
# 5          Balsa              349.820000    0.000000
#
#    Modulus of rupture (MPa)     sd_MR
# 0                  6.440000  1.049861
# 1                 25.200000  2.081599
# 2                  3.516000  0.348000
# 3                 23.328000  5.231376
# 4                  3.920000  0.336190
# 5                 15.636134  0.000000

# %%
selected_columns = ['category', 'Flexural Modulus (MPa)', 'Modulus of rupture (MPa)']
df2 = df[selected_columns]
df2.set_index('category', inplace=True)

# %%
error1_bars = df['sd_FM']
error2_bars = df['sd_MR']
_ = df2.plot( kind= 'bar' ,yerr={'Primary Y': error1_bars, 'Secondary Y': error2_bars}, secondary_y= 'Modulus of rupture (MPa)' , rot= 0,legend=False )
plt.show()

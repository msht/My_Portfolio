# %%
print("Hello Python")
# Out:
# Hello Python

# %%
# This is a single line comment in python

# %%
'''
This is paragraph syntax.
This is also used for multiline comment
'''
# Out:
# '\nThis is paragraph syntax.\nThis is also used for multiline comment\n'

# %%
"""
This is also syntax for
Multiline Comment
"""
# Out:
# '\nThis is also syntax for\nMultiline Comment\n'

# %% [markdown]
# Variables and Datatypes

# %%
_val = "hello"

# %%
var = "hello"

# %%
_ = 10

# %%
print(_)
# Out:
# 10

# %%
1val = 20 #Invalid variable declaration
# Out:
#   File "<ipython-input-10-56be79c57eb4>", line 1
#     1val = 20 #Invalid variable declaration
#        ^
# SyntaxError: invalid syntax

# %%
# Integer
val_1 = 100
print(val_1)
# Out:
# 100

# %%
type(val_1)
# Out:
# int

# %%
val_2 = "Hello Python"
print(val_2)
# Out:
# Hello Python

# %%
type(val_2)
# Out:
# str

# %%
val_3 = 'Hello Python'

# %%
type(val_3)
# Out:
# str

# %%
# Boolean Data type
val_4 = True
val_5 = False

# %%
print(val_5)
# Out:
# False

# %%
# Float Data Type
val_6 = 12.67656655
print(val_6)
# Out:
# 12.67656655

# %%
20 + 30
# Out:
# 50

# %%
20 * 10
# Out:
# 200

# %%
# Complex Numbers
# In Python complex number is form of real + imaginary with 'j'
val_7 = 34+67j
print(val_7)
# Out:
# (34+67j)

# %%
list_1 = []

# Collection of Hetrogeneous Data Types 
list_1 = [100, 'Tom', 'Donald', 'Jerry', 100.3456, 34+56j]

print(list_1)

# %%
# Out:
# [100, 'Tom', 'Donald', 'Jerry', 100.3456, (34+56j), 101010101, 'Tom', 'Mickey', 'Jerry', True, True, False, (45+67j), 23456.9876, 123456789]
